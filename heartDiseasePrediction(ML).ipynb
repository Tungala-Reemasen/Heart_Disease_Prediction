# %% [markdown]
# <a href="https://colab.research.google.com/github/Tungala-Reemasen/Heart_Disease_Prediction/blob/main/heartDiseasePrediction(ML).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("/content/drive/MyDrive/Heart_Disease_Prediction.csv")

# %%
df.head()
# Out:
#    Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0   70    1                4  130          322             0            2
# 1   67    0                3  115          564             0            2
# 2   57    1                2  124          261             0            0
# 3   64    1                4  128          263             0            0
# 4   74    0                2  120          269             0            2
#
#    Max HR  Exercise angina  ST depression  Slope of ST  \
# 0     109                0            2.4            2
# 1     160                0            1.6            2
# 2     141                0            0.3            1
# 3     105                1            0.2            2
# 4     121                1            0.2            1
#
#    Number of vessels fluro  Thallium Heart Disease
# 0                        3         3      Presence
# 1                        0         7       Absence
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 270 entries, 0 to 269
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      270 non-null    int64
#  1   Sex                      270 non-null    int64
#  2   Chest pain type          270 non-null    int64
#  3   BP                       270 non-null    int64
#  4   Cholesterol              270 non-null    int64
#  5   FBS over 120             270 non-null    int64
#  6   EKG results              270 non-null    int64
#  7   Max HR                   270 non-null    int64
#  8   Exercise angina          270 non-null    int64
#  9   ST depression            270 non-null    float64
#  10  Slope of ST              270 non-null    int64
#  11  Number of vessels fluro  270 non-null    int64
#  12  Thallium                 270 non-null    int64
#  13  Heart Disease            270 non-null    object
# ...

# %%
from sklearn.preprocessing import LabelEncoder
heart_disease=['Heart Disease']
df=pd.get_dummies(df,columns=heart_disease,drop_first=True)
df
# Out:
#      Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0     70    1                4  130          322             0            2
# 1     67    0                3  115          564             0            2
# 2     57    1                2  124          261             0            0
# 3     64    1                4  128          263             0            0
# 4     74    0                2  120          269             0            2
# ..   ...  ...              ...  ...          ...           ...          ...
# 265   52    1                3  172          199             1            0
# 266   44    1                2  120          263             0            0
# 267   56    0                2  140          294             0            2
# 268   57    1                4  140          192             0            0
# 269   67    1                4  160          286             0            2
#
# ...

# %%
import seaborn as sns

# %%
sns.displot(df["Max HR"], kind="kde")
plt.xlabel("Maximum heart rate achieved")
# Out:
# Text(0.5, 9.444444444444438, 'Maximum heart rate achieved')

# %%
df["Thallium"].value_counts()
# Out:
# Thallium
# 3    152
# 7    104
# 6     14
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 270 entries, 0 to 269
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      270 non-null    int64
#  1   Sex                      270 non-null    int64
#  2   Chest pain type          270 non-null    int64
#  3   BP                       270 non-null    int64
#  4   Cholesterol              270 non-null    int64
#  5   FBS over 120             270 non-null    int64
#  6   EKG results              270 non-null    int64
#  7   Max HR                   270 non-null    int64
#  8   Exercise angina          270 non-null    int64
#  9   ST depression            270 non-null    float64
#  10  Slope of ST              270 non-null    int64
#  11  Number of vessels fluro  270 non-null    int64
#  12  Thallium                 270 non-null    int64
#  13  Heart Disease_Presence   270 non-null    bool
# ...

# %%
df.head(10)
# Out:
#    Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0   70    1                4  130          322             0            2
# 1   67    0                3  115          564             0            2
# 2   57    1                2  124          261             0            0
# 3   64    1                4  128          263             0            0
# 4   74    0                2  120          269             0            2
# 5   65    1                4  120          177             0            0
# 6   56    1                3  130          256             1            2
# 7   59    1                4  110          239             0            2
# 8   60    1                4  140          293             0            2
# 9   63    0                4  150          407             0            2
#
#    Max HR  Exercise angina  ST depression  Slope of ST  \
# 0     109                0            2.4            2
# ...

# %%
categorized_sex = pd.get_dummies(df["Sex"])

# %%
categorized_sex.columns = ["female", "male"]

# %%
categorized_data = pd.get_dummies(
    data=df,
    columns=["Sex", "Chest pain type", "FBS over 120", "EKG results", "Exercise angina", "Slope of ST", "Number of vessels fluro", "Thallium", "Heart Disease_Presence"],
    drop_first=True,
)
df
# Out:
#      Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0     70    1                4  130          322             0            2
# 1     67    0                3  115          564             0            2
# 2     57    1                2  124          261             0            0
# 3     64    1                4  128          263             0            0
# 4     74    0                2  120          269             0            2
# ..   ...  ...              ...  ...          ...           ...          ...
# 265   52    1                3  172          199             1            0
# 266   44    1                2  120          263             0            0
# 267   56    0                2  140          294             0            2
# 268   57    1                4  140          192             0            0
# 269   67    1                4  160          286             0            2
#
# ...

# %% [markdown]
# **LINEAR REGRESSION**

# %%
from sklearn import metrics
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
le = LabelEncoder()
df['Heart Disease'] = le.fit_transform(df['Heart Disease'])
x = df.drop(['Heart Disease'],axis=1)
y = df['Heart Disease']
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=42)
# Instantiate the Linear Regression model
lireg_model = LinearRegression()
# Train the model
lireg_model.fit(x_train, y_train)
y_pred = lireg_model.predict(x_test)
#calculate accuracy
accuracy = accuracy_score(y_test,y_pred.round())
#print the accuracy
print("The accuracy of the Linear Regression is:",accuracy)
#evaluate the model using various metrices
mse = mean_squared_error(y_test,y_pred)
rmse = mean_squared_error(y_test,y_pred,squared=False)
mae = mean_absolute_error(y_test,y_pred)
r_squared = r2_score(y_test,y_pred)

print("Mean Squared Error :",mse)
print("Root Mean Squared Error :",rmse)
print("Mean Absolute Error :",mae)
print("R-Squared",r_squared)
# Out:
# The accuracy of the Linear Regression is: 0.8395061728395061
# Mean Squared Error : 0.13113471358398335
# Root Mean Squared Error : 0.3621252733295252
# Mean Absolute Error : 0.2902213923536249
# R-Squared 0.4512915460302839

# %% [markdown]
# **LOGISTIC REGRESSION**

# %%
from sklearn.linear_model import LogisticRegression
le = LabelEncoder()
df['Heart Disease'] = le.fit_transform(df['Heart Disease'])
x = df.drop(['Heart Disease'],axis=1)
y = df['Heart Disease']
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=42)
# Instantiate the Logistic Regression model
logreg_model = LogisticRegression()
# Train the model
logreg_model.fit(x_train, y_train)
# Make predictions on the test set
y_pred = logreg_model.predict(x_test)
# Evaluate the model
class_report = classification_report(y_test, y_pred)
# Display the results
print("The accuracy of the Logistic Regression is:",metrics.accuracy_score(y_pred,y_test))
print("\nClassification Report:\n", class_report)
# Out:
# The accuracy of the Logistic Regression is: 0.8641975308641975
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.85      0.94      0.89        49
#            1       0.89      0.75      0.81        32
#
#     accuracy                           0.86        81
#    macro avg       0.87      0.84      0.85        81
# weighted avg       0.87      0.86      0.86        81
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
